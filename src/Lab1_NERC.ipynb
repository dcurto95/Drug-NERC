# %% [markdown]
# # Lab AHLT Drug NER - Part 1
# ### Authors: David Curto & David Hilazo

# %% [markdown]
# This is the first part of the deliverable which is based on building a rule-based NERC recognizes and classifies drug names in a text. In this first laboratory there are 2 goals that must be achieved:
#
# 1. Implement a rule-based NERC with no external knowledge and achieve at least a F1 score of 0.5 on Devel dataset
# 2. Implement a rule-based NERC with external knowledge and achieve at least a F1 score of 0.6 on Devel dataset

# %%
import os
import re
import string
import xml.etree.ElementTree as ET
from collections import Counter

import nltk
from chemdataextractor.nlp.tokenize import ChemWordTokenizer
from nltk import word_tokenize, QuadgramCollocationFinder
from nltk.corpus import stopwords

# %% [markdown]
# **Read and extract info from the XML file**
#
# This first function reads the XML file using the The ElementTree XML API and returns the root of the tree that will be used to parse all the information needed.
#
# The second one retrieves the information that will be used in the following functions which is the id of the sentence and the text that it contains.

# %%
def parse_xml(file):
    tree = ET.parse(file)
    return tree.getroot()

# %%
def get_sentence_info(child):
    return child.get('id'), child.get('text')

# %% [markdown]
# **Tokenizers**
#
#
# Once we have the sentence text we have to apply some transformations in order to be able to manipulate them easily. This first preprocessing step is called  word Tokenization which splits the sentence into tokens.
#
# In order to do that, we have tested two different tokenizers. The first word tokenizer tested is one of the most well known in NLP task which is the NLTK word tokenizer. However, also we tested one implemented by a tool named ChemDataExtractor which is designed for automatically extracting chemical information from scientific documents. As this tokenizer is more field oriented, it handles better some chemical word formations than the NLTK word tokenizer which is less field oriented.
#
# For this reason, we decided to just use the ChemWordTokenizer as it retrieves better the tokens for specific cases.
#
# Both of these function returns all the tokens founds and its starting and ending position for each one of them within the sentence.

# %%
def chem_tokenize(text):
    cwt = ChemWordTokenizer()
    tokens = cwt.tokenize(text)
    token_indexs = cwt.span_tokenize(text)
    tokenized_info = []
    for token_index, token in zip(token_indexs, tokens):
        tokenized_info.append((token, token_index[0], token_index[1] - 1))
    return tokenized_info


def tokenize(text):
    tokenized_sent = word_tokenize(text)
    tokenized_info = []
    current_index = 0

    for word in tokenized_sent:

        if not re.match("[" + string.punctuation + "]", word):
            for match in re.finditer(word, text):
                if match.start() >= current_index:
                    tokenized_info.append((word, match.start(), match.end() - 1))
                    current_index = match.end() - 1
                    break
    return tokenized_info

# %% [markdown]
# **Get external resources**
#
# This function reads the external file named DrugBank and stores its information (name , type of drug).
# This information will only be used in the second task of this exercise where external resources are available

# %%
def get_external_resources():
    file = open('../resources/DrugBank.txt', 'r', encoding="utf8")
    Lines = file.readlines()

    resources = {}

    # Strips the newline character
    for line in Lines:
        value = line.split("|")
        resources[value[0]] = value[1][:-1]
    return resources

# %% [markdown]
# **Extract entities**
#
# This function is the main core of the application as it is where all the rules are defined in order to classify if a token belongs to any of the 4 possible types available.
#
# In this function there's a section of code that will be executed only when the flag with resources is activated. In this section of code it will use the information retrieved from the external resource file Drugbank to check if the word was inside that document and the type that it had. In addition to that, we use the external corpus of nltk to look if the word belongs to the stop word corpus, if that's the case it will skip the classification task as it won't belong to any of the 4 types.
#
# All the other rules are shared in both contexts independently if we use external resources or not. These rules were formed by looking at specific features that were common just in each type. Some example of this rules are: looking at specific prefixes, suffixes, words, specific characters, looking if the word was uppercase and many more.

# %%
def extract_entities(token_list, entities_dict, with_resources=False):
    entities = []
    previous_token_offset = (0, 0)
    stop_words = set(stopwords.words('english'))

   
    for token in token_list:
        if with_resources:
            if token[0].lower() in entities_dict:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': entities_dict[token[0].lower()]})
                previous_token_offset = (token[1], token[2])
                continue
            if token[0] in entities_dict:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': entities_dict[token[0]]})
                previous_token_offset = (token[1], token[2])
            if token[0].lower() in stop_words:
                continue
        
        # Common stopwords found in the training
        if token[0].lower() in {'of', 'the', 'and', 'in', 'with', 'to', 'be', 'or', 'is', 'not', 'by', 'for',
                                'should', 'on', 'that', 'been', 'have', 'other', 'was', 'when', 'are', 'as', 'were',
                                'no', 'has', 'these', 'an', 'this', 'such', 'at', 'from', 'it', 'if', 'there', 'after',
                                'which', 'can', 'between', 'during', 'because', 'both', 'than', 'did', 'its', 'but',
                                'some', 'who', 'any'}:
            continue
            
        if token[0].lower() == "aspirin":
            entities.append({'name': token[0],
                             'offset': str(token[1]) + "-" + str(token[2]),
                             'type': "brand"})
            previous_token_offset = (token[1], token[2])
            continue
         
        # Assign token to drug_n if contains a (  and the length is greater than 1
        if '(' in token[0] and len(token[0]) > 1:
            if len(entities) > 0 and previous_token_offset[1] + 2 == token[1]:
                entities[-1]['name'] += " " + token[0]
                entities[-1]['offset'] = str(previous_token_offset[0]) + "-" + str(token[2])
            else:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': "drug_n"})
                previous_token_offset = (token[1], token[2])
            continue
        # Check letters in lowercase separeted by a hyphen   
        if re.search("[a-z][\-][a-z]", token[0]) and re.search("^(\d+[\-\.]\d+)$|^(\d+\.\d+\-\d+\.\d+)$",
                                                               token[0]) is None:
            if len(entities) > 0 and previous_token_offset[1] + 2 == token[1]:
                entities[-1]['name'] += " " + token[0]
                entities[-1]['offset'] = str(previous_token_offset[0]) + "-" + str(token[2])
            else:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': "group"})
                previous_token_offset = (token[1], token[2])
            continue
        
        # Check word containing special characters and that it's not only formed by numbers
        if re.search("\w[_%()\-]\w", token[0]) and re.search("^(\d+[\-\.]\d+)$|^(\d+\.\d+\-\d+\.\d+)$",
                                                             token[0]) is None:
            if len(entities) > 0 and previous_token_offset[1] + 2 == token[1]:
                entities[-1]['name'] += " " + token[0]
                entities[-1]['offset'] = str(previous_token_offset[0]) + "-" + str(token[2])
            else:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': "drug_n"})
                previous_token_offset = (token[1], token[2])
            continue
        
        # Check is word is uppercase
        if token[0].isupper():
            
            #Look for vowels 
            pattern = re.compile("[AEIOU]")
            if len(entities) > 0 and previous_token_offset[1] + 2 == token[1]:
                entities[-1]['name'] += " " + token[0]
                entities[-1]['offset'] = str(previous_token_offset[0]) + "-" + str(token[2])
            elif not bool(pattern.search(token[0])):
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': "drug_n"})
                previous_token_offset = (token[1], token[2])
            else:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': "brand"})
                previous_token_offset = (token[1], token[2])
            continue
        
        # Check if the token is in the list of this frequent words and comes from previous token
        if len(entities) > 0 and previous_token_offset[1] + 2 == token[1] and any(
                substring in token[0].lower() for substring in
                ['agent', 'inhibitor', 'blocker', 'drug', 'type', 'medication', 'contraceptive', 'anticoagulants']):
            entities[-1]['name'] += " " + token[0]
            entities[-1]['offset'] = str(previous_token_offset[0]) + "-" + str(token[2])
            entities[-1]['type'] = "group"
            continue
        
        # Check if the token is in this list
        if token[0].lower() in ['digoxin', 'warfarin', 'phenytoin', 'theophylline', 'lithium', 'ketoconazole',
                                'cimetidine',
                                'alcohol', 'cyclosporine', 'erythromycin', 'tricyclic antidepressants', 'aspirin',
                                'carbamazepine', 'rifampin', 'amiodarone', 'quinidine', 'phenobarbital', 'indinavir',
                                'propranolol', 'methotrexate', 'diltiazem', 'cisapride',
                                'ethanol']:
            if len(entities) > 0 and previous_token_offset[1] + 2 == token[1]:
                entities[-1]['name'] += " " + token[0]
                entities[-1]['offset'] = str(previous_token_offset[0]) + "-" + str(token[2])
            else:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': "drug"})
                previous_token_offset = (token[1], token[2])
            continue
        
        # Check if the token is in the list of this frequent words and comes from previous token
        if any(substring in token[0].lower() for substring in
               ['anticoagulant', 'corticosteroid', 'NSAID', 'antacid', 'contraceptive', 'diuretic', 'barbiturate']):
            if len(entities) > 0 and previous_token_offset[1] + 2 == token[1]:
                entities[-1]['name'] += " " + token[0]
                entities[-1]['offset'] = str(previous_token_offset[0]) + "-" + str(token[2])
            else:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': "group"})
                previous_token_offset = (token[1], token[2])
            continue

        suffixes = (
            "afil", "asone", "bicin", "bital", "caine", "cillin", "cycline", "azole", "dipine",
            "dronate", "eprazole", "fenac", "floxacin", "gliptin", "glitazone", "iramine", "lamide", "mab",
            "mustine", "mycin", "nacin", "nazole", "olol", "olone", "olone", "onide", "oprazole", "parin",
            "phylline", "pramine", "pril", "profen", "ridone", "sartan", "semide", "setron", "setron", "statin",
            "tadine", "tadine", "terol", "thiazide", "tinib", "trel", "tretin", "triptan", "tyline", "vudine",
            "zepam", "zodone", "zolam", "zosin", "ine")
        
        # Check if token contains any of these suffixes
        if token[0].endswith(suffixes):
            if len(entities) > 0 and previous_token_offset[1] + 2 == token[1]:
                entities[-1]['name'] += " " + token[0]
                entities[-1]['offset'] = str(previous_token_offset[0]) + "-" + str(token[2])
            else:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': "drug"})
                previous_token_offset = (token[1], token[2])
            continue

        prefixes = ("anti")
        
        # Check for prefixes
        if token[0].startswith(prefixes) or "POC" in token[0]:
            if len(entities) > 0 and previous_token_offset[1] + 2 == token[1]:
                entities[-1]['name'] += " " + token[0]
                entities[-1]['offset'] = str(previous_token_offset[0]) + "-" + str(token[2])
            else:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': "group"})
                previous_token_offset = (token[1], token[2])
            continue
        
        # Check PoS tag
        if token[0][0].isupper() and nltk.pos_tag([token[0]])[0][1][0] == 'N':
            if len(entities) > 0 and previous_token_offset[1] + 2 == token[1]:
                entities[-1]['name'] += " " + token[0]
                entities[-1]['offset'] = str(previous_token_offset[0]) + "-" + str(token[2])
            else:
                entities.append({'name': token[0],
                                 'offset': str(token[1]) + "-" + str(token[2]),
                                 'type': "brand"})
                previous_token_offset = (token[1], token[2])
            continue
    return entities

# %%
def output_entities(sid, entities, output_file):
    for entity in entities:
        output_file.write(sid + "|" + entity['offset'] + "|" + entity['name'] + "|" + entity['type'] + "\n")

# %%
def evaluate(inputdir, outputfile):
    return os.system("java -jar ../eval/evaluateNER.jar " + inputdir + " ../output/" + outputfile)

# %% [markdown]
# **NOTE:** If you want to evaluate using the Test dataset, just uncomment the line of code below the input directory

# %%
output_file_name = "task9.1_out_1.txt"
input_directory = '../data/Devel/'
#Uncomment the following line for using the Test dataset
#input_directory = '../data/Test-NER/'  

entities_dict = get_external_resources()

# %% [markdown]
# **Without resources**
#
# This section of code is in charge of evaluating the model. In this case the objective was to achieve and F1 score of **0.5** using only the training information.

# %%
output_file = open('../output/' + output_file_name, 'w+')
for filename in os.listdir(input_directory):
    root = parse_xml(input_directory + filename)
    # print(" - File:", filename)
    for child in root:
        sid, text = get_sentence_info(child)
        token_list = chem_tokenize(text)
        entities = extract_entities(token_list, entities_dict, with_resources=False)
        output_entities(sid, entities, output_file)

# Close the file
output_file.close()
evaluate(input_directory, output_file_name) # Shown in console
# Out:
# 0

# %% [markdown]
# <p style="color:red; font-size:14px">WARNING: The execution of the evaluation and the messages are shown in the console. Please look at the console in order to see what are the model's metrics</p>

# %% [markdown]
# **With resources**
#
# This section of code is in charge of evaluating the model. In this case the objective was to achieve and F1 score of **0.6** using  the training information plus external resources.

# %%
output_file = open('../output/' + output_file_name, 'w+')
for filename in os.listdir(input_directory):
    root = parse_xml(input_directory + filename)
    # print(" - File:", filename)
    for child in root:
        sid, text = get_sentence_info(child)
        token_list = chem_tokenize(text)
        entities = extract_entities(token_list, entities_dict, with_resources=True)
        output_entities(sid, entities, output_file)

# Close the file
output_file.close()
evaluate(input_directory, output_file_name) # Shown in console
# Out:
# 0

# %% [markdown]
# <p style="color:red; font-size:14px">WARNING: The execution of the evaluation and the messages are shown in the console. Please look at the console in order to see what are the model's metrics</p>

# %% [markdown]
# ### Get train info
#
# These following functions were implemented to retrieve information from the training set in order to be able to construct rules that differentiate between the types.
#
# We study the frequency of appearance of some prefixes for each type, extract which were the  longest common prefix, the previous and current PoS tag, the quadgrams, word frequency and many more.
#
# Apart from the knowledge retrieved by looking at the output of these functions we also generate an Excel file for each type in order to extract more information in a more visual way and easier to interpret like counting the characters, common words and its frequency, common terminations, etc.
#
# Finally, we implemented a code that was extremely useful for us to increase the accuracy of our model that is based on printing the missing data that the model wasn't able to detect and also those that were misclassified. This information made us tune some rules and create new ones in order to improve the performance of our model

# %%
def get_postag_counts(token_list, entities, previous_tag_dict, entity_tag_dict):
    for entity in entities:
        entity_token = entity
        if " " in entity_token:
            entity_token = entity_token.split(" ")[0]
        if "-" in entity_token:
            entity_token = entity_token.split("-")[0]
        if "(" in entity_token:
            entity_token = entity_token.split("(")[0]
        if "." in entity_token:
            entity_token = entity_token.split(".")[0]

        for i, token in enumerate(token_list):
            if entity_token in token:
                entity_index = i
        tags = nltk.pos_tag(token_list)

        entity_tag = tags[entity_index][1]
        previous_tag = tags[entity_index - 1][1]

        if entity_tag not in entity_tag_dict:
            entity_tag_dict[entity_tag] = 0
        entity_tag_dict[entity_tag] += 1

        if previous_tag not in previous_tag_dict:
            previous_tag_dict[previous_tag] = 0
        previous_tag_dict[previous_tag] += 1

    return previous_tag_dict, entity_tag_dict


def get_truth_entities(child):
    return [ent.get('text') for ent in child.findall('entity')], [ent.get('type') for ent in child.findall('entity')]


def longestCommonPrefix(strs):
    longest_pre = ""
    if not strs: return longest_pre
    shortest_str = min(strs, key=len)
    for i in range(len(shortest_str)):
        if all([x.startswith(shortest_str[:i + 1]) for x in strs]):
            longest_pre = shortest_str[:i + 1]
        else:
            break
    return longest_pre


def print_truth_patterns(input_directory):
    all_entities = []
    all_entities_type = []
    all_token_list = []

    previous_tag_dict = {}
    entity_tag_dict = {}

    multiple_words_by_type = {}

    for filename in os.listdir(input_directory):
        root = parse_xml(input_directory + filename)
        # print(" - File:", filename)

        for child in root:
            sid, text = get_sentence_info(child)
            token_list = word_tokenize(text)
            entities, entities_type = get_truth_entities(child)

            for entity, type in zip(entities, entities_type):
                if len(entity.split(' ')) > 1:
                    if type not in multiple_words_by_type:
                        multiple_words_by_type[type] = 0
                    multiple_words_by_type[type] += 1

            all_entities.append(entities)
            all_entities_type.append(entities_type)
            all_token_list.append(token_list)

            get_postag_counts(token_list, entities, previous_tag_dict, entity_tag_dict)
    sorted_previous_tag = {k: v for k, v in
                           sorted(previous_tag_dict.items(), key=lambda item: item[1], reverse=True)}
    sorted_entity_tag = {k: v for k, v in sorted(entity_tag_dict.items(), key=lambda item: item[1], reverse=True)}

    # print("LONGEST PREFIX:", longestCommonPrefix(all_entities))
    print("MULTIPLE WORDS COUNT:", multiple_words_by_type, "\n")

    all_entities = [item for sublist in all_entities for item in sublist]
    all_entities_type = [item for sublist in all_entities_type for item in sublist]

    cnt = Counter(all_entities)
    print({k:v for k,v in cnt.items() if v > 4})
    
    print("\nStarts with 'phe' prefix:")
    for entity, entity_type in zip(all_entities, all_entities_type):
        if entity.startswith("phe"):
            print(entity, "-", entity_type)

    all_entities.insert(0, "  ")
    all_entities.append("  ")
    entities_string = "  ".join(all_entities)

    finder = QuadgramCollocationFinder.from_words(entities_string)
    finder.apply_freq_filter(10)

    quadgrams = [tr for tr in finder.ngram_fd.items()]
    quadgrams = sorted(quadgrams, key=lambda tup: tup[1], reverse=True)

    for quadgram in quadgrams:
        if quadgram[0][0] == ' ':
            # Prefix
            prefix = ''.join(quadgram[0][1:])
            entities_with_prefix = [ent for ent in all_entities if ent.startswith(prefix)]
            entities_type_with_prefix = {}
            for ent, ent_type in zip(all_entities, all_entities_type):
                if ent.startswith(prefix):
                    if ent_type not in entities_type_with_prefix:
                        entities_type_with_prefix[ent_type] = 0
                    entities_type_with_prefix[ent_type] += 1
            if entities_type_with_prefix:
                print("\nLongest Prefix:", longestCommonPrefix(entities_with_prefix), len(entities_with_prefix), "\n")
                print(entities_type_with_prefix, "\n")
    print("PREVIOUS TAGS:\n", sorted_previous_tag, "\n")
    print("ENTITY TAGS:\n", sorted_entity_tag, "\n")
    print("QUADGRAMS:\n", quadgrams, "\n")

print_truth_patterns(input_directory)
# Out:
# MULTIPLE WORDS COUNT: {'group': 237, 'drug': 74, 'drug_n': 9, 'brand': 3}
#
# {'antibiotics': 5, 'ofloxacin': 5, 'digoxin': 21, 'thiazide diuretics': 15, 'PCP': 15, 'Carbamazepine': 5, 'carbamazepine': 15, 'tricyclic antidepressants': 5, 'KRM-1648': 5, 'rifampicin': 5, 'rifabutin': 8, 'sildenafil': 9, 'amphetamine': 6, 'cocaine': 5, '3H-spiroperidol': 5, 'neuroleptics': 6, 'apomorphine': 7, 'naloxone': 10, 'beta-endorphin': 9, 'morphine': 12, '(+)-NANM': 7, '(-)-NANM': 8, 'gentamicin': 6, 'vitamin D': 19, '1,25(OH)2D3': 7, 'norepinephrine': 15, 'desipramine': 7, 'probenecid': 7, 'ampicillin': 6, 'Probenecid': 5, 'alcohol': 8, 'Ketoconazole': 6, 'indomethacin': 7, 'aspirin': 11, 'cyclosporine': 9, 'erythromycin': 7, 'atorvastatin': 18, 'colestipol': 5, 'cimetidine': 7, 'ethinyl estradiol': 9, 'warfarin': 24, 'HMG-CoA reductase inhibitors': 5, 'ketoconazole': 12, 'nelfinavir': 15, 'azithromycin': 12, 'indinavir': 5, 'theophylline': 13, 'phenytoin': 20, 'baclofen': 6, 'WELLBUTRIN': 7, 'bupropion': 17, 'phenobarbital': 14, 'levodopa': 6, 'Cholestyramine': 5, 'Phenytoin': 7, 'Phenobarbital': 6, 'Thiazides': 7, 'antacids': 7, 'Antacids': 5, 'cefdinir': 11, 'OMNICEF': 5, 'iron': 11, 'diuretics': 7, 'cholestyramine': 5, 'cerivastatin sodium': 11, 'NSAIDs': 8, 'diuretic': 6, 'lithium': 21, 'Cerubidine': 5, 'methotrexate': 9, 'entacapone': 8, 'TARCEVA': 5, 'saquinavir': 6, 'hormonal contraceptives': 8, 'nonhormonal contraceptive product': 6, 'felbamate': 18, 'combination hormonal contraceptives': 7, 'Felbatol': 23, 'valproate': 9, 'TRICOR': 7, 'fenofibrate': 5, 'IRESSA': 5, 'quinolones': 6, 'grepafloxacin': 11, 'terfenadine': 5, 'imatinib': 6, 'Gleevec': 13, 'rifampin': 6, 'INDOCIN': 28, 'ketoprofen': 17, 'L-glutamine': 7, 'amphetamines': 7, 'Amphetamines': 11, 'naproxen': 8, 'VIRACEPT': 23}
#
# Starts with 'phe' prefix:
# phencyclidine - drug_n
# phencyclidine - drug_n
# phenothiazines - group
# phenytoin - drug
# phenobarbital - drug
# phenytoin - drug
# phenelzine - drug
# phenytoin - drug
# phenobarbital - drug
# phenytoin - drug
# phenobarbital - drug
# phenothiazines - group
# phenylbutazone - drug
# phenytoin - drug
# phenobarbital - drug
# phenobarbital - drug
# phenytoin - drug
# phenobarbital - drug
# phenytoin - drug
# phenytoin - drug
# phenytoin - drug
# phenytoin - drug
# phenytoin - drug
# phenytoin - drug
# phenytoin - drug
# phenytoin - drug
# phenytoin - drug
# phenobarbital - drug
# phenobarbital - drug
# phenobarbital - drug
# phenobarbital - drug
# phenytoin - drug
# phenobarbital - drug
# phenytoin - drug
# phenytoin - drug
# phenobarbital - drug
# phenelzine sulfate - drug
# phenobarbital - drug
# phenobarbital - drug
# phenytoin - drug
# phenytoin - drug
#
# Longest Prefix: ant 45
#
# {'drug': 20, 'group': 17, 'drug_n': 2, 'brand': 6}
#
#
# Longest Prefix: phen 41
#
# {'drug_n': 2, 'group': 5, 'brand': 6, 'drug': 28}
#
#
# Longest Prefix: diuretic 13
#
# {'drug': 5, 'group': 6, 'brand': 2}
#
#
# Longest Prefix: Ant 33
#
# {'group': 11, 'drug': 19, 'brand': 3}
#
#
# Longest Prefix: contraceptive 5
#
# {'drug': 5}
#
#
# Longest Prefix: keto 29
#
# {'drug': 20, 'group': 4, 'brand': 5}
#
#
# Longest Prefix: pro 20
#
# {'drug': 13, 'group': 7}
#
#
# Longest Prefix: INDOCIN 28
#
# {'drug': 13, 'brand': 7, 'group': 8}
#
#
# Longest Prefix: vitamin 25
#
# {'group': 11, 'drug': 12, 'brand': 2}
#
#
# Longest Prefix: dig 24
#
# {'drug': 21, 'group': 1, 'brand': 2}
#
#
# Longest Prefix: warfarin 24
#
# {'group': 4, 'drug': 17, 'brand': 2, 'drug_n': 1}
#
#
# Longest Prefix: Felba 24
#
# {'group': 4, 'drug': 17, 'brand': 3}
#
#
# Longest Prefix: beta 23
#
# {'drug': 17, 'brand': 1, 'group': 5}
#
#
# Longest Prefix: VIRACEPT 23
#
# {'group': 4, 'drug': 16, 'brand': 2}
#
#
# Longest Prefix: nor 22
#
# {'drug': 17, 'group': 4, 'brand': 1}
#
#
# Longest Prefix: lithium 22
#
# {'drug': 18, 'group': 2, 'brand': 2}
#
#
# Longest Prefix: rifa 21
#
# {'drug': 13, 'brand': 6, 'group': 2}
#
#
# Longest Prefix: thi 20
#
# {'drug': 9, 'group': 10, 'brand': 1}
#
#
# Longest Prefix: tri 20
#
# {'drug': 12, 'drug_n': 1, 'group': 5, 'brand': 2}
#
#
# Longest Prefix: carb 18
#
# {'group': 2, 'drug': 12, 'brand': 2, 'drug_n': 2}
#
#
# Longest Prefix: amp 19
#
# {'drug': 11, 'drug_n': 1, 'group': 7}
#
#
# Longest Prefix: sodium acid phosphate 1
#
# {'drug': 1}
#
#
# Longest Prefix: atorvastatin 18
#
# {'brand': 2, 'drug': 14, 'group': 2}
#
#
# Longest Prefix: hormonal contraceptives 8
#
# {'drug': 4, 'group': 3, 'drug_n': 1}
#
#
# Longest Prefix: felbamate 18
#
# {'drug': 12, 'drug_n': 1, 'group': 4, 'brand': 1}
#
#
# Longest Prefix: cer 17
#
# {'drug_n': 2, 'drug': 14, 'group': 1}
#
#
# Longest Prefix: bupropion 17
#
# {'drug': 10, 'drug_n': 3, 'group': 4}
#
#
# Longest Prefix: Phen 15
#
# {'drug_n': 1, 'drug': 9, 'brand': 2, 'group': 3}
#
#
# Longest Prefix: PCP 15
#
# {'drug_n': 7, 'group': 2, 'drug': 6}
#
#
# Longest Prefix: calci 12
#
# {'group': 3, 'drug': 6, 'brand': 3}
#
#
# Longest Prefix: estrogen 1
#
# {'brand': 1}
#
#
# Longest Prefix: met 15
#
# {'brand': 2, 'group': 3, 'drug': 10}
#
#
# Longest Prefix: nelfinavir 15
#
# {'drug': 11, 'brand': 3, 'group': 1}
#
#
# Longest Prefix: theo 15
#
# {'drug': 12, 'group': 3}
#
#
# Longest Prefix: drugs 1
#
# {'drug': 1}
#
#
# Longest Prefix: cef 14
#
# {'brand': 2, 'group': 6, 'drug': 5, 'drug_n': 1}
#
#
# Longest Prefix: non 14
#
# {'group': 7, 'drug': 6, 'brand': 1}
#
#
# Longest Prefix: ind 12
#
# {'group': 1, 'drug': 7, 'brand': 4}
#
#
# Longest Prefix: iron 13
#
# {'drug': 7, 'group': 3, 'brand': 1, 'drug_n': 2}
#
#
# Longest Prefix: Amp 13
#
# {'drug': 9, 'group': 4}
#
#
# Longest Prefix: Gleevec 13
#
# {'drug': 8, 'brand': 4, 'group': 1}
#
#
# Longest Prefix: morphine 12
#
# {'group': 2, 'drug_n': 5, 'drug': 4, 'brand': 1}
#
#
# Longest Prefix: azithromycin 12
#
# {'drug': 11, 'group': 1}
#
#
# Longest Prefix: hyd 7
#
# {'brand': 1, 'drug_n': 1, 'drug': 2, 'group': 3}
#
#
# Longest Prefix: ami 10
#
# {'drug': 6, 'group': 3, 'brand': 1}
#
#
# Longest Prefix: aspirin 11
#
# {'brand': 4, 'group': 1, 'drug': 6}
#
#
# Longest Prefix: eth 11
#
# {'group': 4, 'drug': 7}
#
#
# Longest Prefix: fosinopril 11
#
# {'group': 2, 'drug': 6, 'drug_n': 2, 'brand': 1}
#
#
# Longest Prefix: grepafloxacin 11
#
# {'drug': 9, 'group': 2}
#
#
# Longest Prefix: clo 10
#
# {'drug_n': 4, 'group': 2, 'drug': 4}
#
#
# Longest Prefix: sildenafil 10
#
# {'drug': 8, 'brand': 1, 'group': 1}
#
#
# Longest Prefix: chlor 9
#
# {'drug': 4, 'drug_n': 1, 'group': 4}
#
#
# Longest Prefix: naloxone 10
#
# {'drug_n': 8, 'drug': 2}
#
#
# Longest Prefix: cyclo 10
#
# {'group': 3, 'drug_n': 1, 'drug': 5, 'brand': 1}
#
#
# Longest Prefix: combination hormonal contraceptives 7
#
# {'drug': 3, 'group': 4}
#
#
# Longest Prefix: MAO 9
#
# {'drug': 6, 'group': 3}
#
#
# Longest Prefix: Thiazide 10
#
# {'group': 7, 'drug': 3}
#
#
# Longest Prefix: quin 10
#
# {'drug': 6, 'group': 4}
#
#
# Longest Prefix: valpro 10
#
# {'drug': 6, 'brand': 4}
#
# PREVIOUS TAGS:
# %%
import json

# Using readlines()
file1 = open('goldNER.txt', 'r')
Lines = file1.readlines()

truth = {}

# Strips the newline character
for line in Lines:
    value = line.split("|")
    if value[0] not in truth:
        truth[value[0]] = []
    truth[value[0]].append((value[-2], value[-1]))

# Using readlines()
file1 = open('../output/task9.1_out_1.txt', 'r')
Lines = file1.readlines()

output = {}
wrong_entities = []
new_sent = ""
matched_entities = []
missing = []

# Strips the newline character
for line in Lines:
    value = line.split("|")
    if value[0] not in output:
        output[value[0]] = []
    output[value[0]].append((value[-2], value[-1]))

    if new_sent != value[0] and new_sent != "":
        if new_sent in truth:
            missing += [item for item in truth[new_sent] if item not in matched_entities]
        matched_entities = []
        new_sent = value[0]

    if new_sent == "":
        new_sent = value[0]

    if value[0] in truth and (value[-2], value[-1]) in truth[value[0]]:
        matched_entities.append((value[-2], value[-1]))
    else:
        wrong_entities.append((value[-2], value[-1]))

missing_dict = {}
for ent, type in missing:
    if type[:-1] not in missing_dict:
        missing_dict[type[:-1]] = []
    missing_dict[type[:-1]].append(ent)

wrong_entities_dict = {}
for ent, type in wrong_entities:
    if type[:-1] not in wrong_entities_dict:
        wrong_entities_dict[type[:-1]] = []
    wrong_entities_dict[type[:-1]].append(ent)

print("MISSING:\n", json.dumps(missing_dict, indent=4))
print("\n\n")
print("WRONG:\n", json.dumps(wrong_entities_dict, indent=4))
# Out:
# MISSING:
#  {
#     "group": [
#         "fluoroquinolones",
#         "thiazide diuretics",
#         "atypical antipsychotic",
#         "tricyclic antidepressant",
#         "tricyclic antidepressant",
#         "tricyclic antidepressants",
#         "selective serotonin reuptake inhibitors",
#         "SSRIs",
#         "SSRI",
#         "nitrate",
#         "benzodiazepine",
#         "neuroleptics",
#         "neuroleptics",
#         "neuroleptics",
#         "neuroleptics",
#         "calcium-channel blockers",
#         "Slow-channel calcium blockers",
#         "calcium blockers",
#         "aminoglycoside antibiotic",
#         "radiopharmaceutical",
#         "vitamin D",
#         "vitamin D",
#         "antiestrogen",
#         "vitamin-D",
#         "estrogen",
#         "immunodepressant",
#         "Bacteriostatic Antibiotics",
#         "sulfonamides",
#         "tetracyclines",
#         "penicillins",
#         "5HT3 Antagonists",
#         "5HT3 antagonist class",
#         "Antihypertensive Medication",
#         "Vasodilators",
#         "vasodilators",
#         "Dopamine Antagonists",
#         "dopamine agonist",
#         "dopamine antagonists",
#         "neuroleptics",
#         "phenothiazines",
#         "butyrophenones",
#         "thioxanthenes",
#         "neuroleptics",
#         "dopamine agonists",
#         "beta-blocking agent",
#         "Calcium channel blockers",
#         "beta blocker",
#         "beta blockers",
#         "beta blockers",
#         "beta blockers",
#         "fibric acid derivatives",
#         "azole antifungals",
#         "HMG-CoA reductase inhibitors",
#         "HMG-CoA reductase inhibitors",
#         "HMG-CoA reductase inhibitor",
#         "macrolides",
#         "aminoglycosides",
#         "curare-like compounds",
#         "botulinum toxin",
#         "tricyclics",
#         "Type 1C antiarrhythmics",
#         "steroids",
#         "vitamin D analogues",
#         "fat soluble vitamins",
#         "vitamin D",
#         "Digitalis",
#         "Vitamin D",
#         "digitalis",
#         "vitamin D",
#         "vitamin D",
#         "vitamin D analogues",
#         "vitamin D",
#         "Vitamin D",
#         "vitamin D analogues",
#         "vitamin D",
#         "Antihistamines",
#         "tricyclic antidepressants",
#         "CNS depressants",
#         "Sympathomimetic amines",
#         "veratrum alkaloids",
#         "sympathomimetics",
#         "beta adrenergic blockers",
#         "Iron Supplements",
#         "iron supplement",
#         "vitamins",
#         "iron supplements",
#         "cephalosporins",
#         "aminoglycoside antibiotics",
#         "aminoglycosides",
#         "aminoglycosidic antibiotics",
#         "Immunosuppressive Drugs",
#         "Fibric Acid Derivatives",
#         "Azole Antifungals",
#         "ANTACID",
#         "angiotensin- converting enzyme (ACE) inhibitors",
#         "betablockers",
#         "calcium-channel blockers",
#         "nonsteroidal anti-inflammatory drugs",
#         "NSAIDs",
#         "thiazide diuretics",
#         "narcotics",
#         "Antidiabetic drugs",
#         "resins",
#         "resins",
#         "thiazide diuretics",
#         "Skeletal muscle relaxants",
#         "muscle relaxant",
#         "Non-steroidal Anti-inflammatory Drugs",
#         "non-steroidal anti-inflammatory agent",
#         "loop diuretics",
#         "potassium-sparing diuretics",
#         "non-steroidal anti-inflammatory agents",
#         "vitamin D",
#         "fat soluble vitamins",
#         "vitamin D",
#         "Digitalis",
#         "Vitamin D",
#         "digitalis",
#         "vitamin D",
#         "vitamin D",
#         "vitamin D",
#         "vitamin D",
#         "Vitamin D",
#         "vitamin D",
#         "vitamin D",
#         "benzodiazepines",
#         "narcotics",
#         "phenothiazines",
#         "monoamine oxidase inhibitors",
#         "HMG-CoA reductase inhibitor",
#         "xanthine bronchodilators",
#         "sympathomimetic bronchodilators",
#         "dopa decarboxylase inhibitor",
#         "dopa decarboxylase inhibitor",
#         "dopa decarboxylase inhibitor",
#         "tricyclic antidepressant",
#         "coumarin-derivative anticoagulants",
#         "synthetic estrogens",
#         "hormonal contraceptives",
#         "progestin",
#         "progestational contraceptives",
#         "progestins",
#         "nonhormonal contraceptive product",
#         "Antibiotics",
#         "synthetic steroids",
#         "nonhormonal contraceptive product",
#         "hormonal contraceptives",
#         "coumarin derivatives",
#         "hormonal contraceptives",
#         "progestins",
#         "nonhormonal contraceptive product",
#         "synthetic estrogens",
#         "Benzodiazepines",
#         "hormonal contraceptives",
#         "benzodiazepines",
#         "hormonal contraceptives",
#         "hormonal contraceptives",
#         "rifamycins",
#         "combination hormonal contraceptives",
#         "hormonal contraceptives",
#         "Non-nucleoside reverse transcriptase inhibitors",
#         "NNRTIs",
#         "combination hormonal contraceptives",
#         "nonhormonal contraceptive product",
#         "combination hormonal contraceptives",
#         "nonhormonal contraceptive product",
#         "combination hormonal contraceptives",
#         "progestins",
#         "nonhormonal contraceptive product",
#         "hormonal contraceptives",
#         "Combination hormonal contraceptives",
#         "Tricyclic antidepressants",
#         "combination hormonal contraceptives",
#         "combination hormonal contraceptives",
#         "combination hormonal contraceptives",
#         "Antiepileptic Drugs",
#         "AEDs",
#         "AEDs",
#         "AED",
#         "AED",
#         "Antiepileptic Drugs",
#         "Antiepileptic Drugs",
#         "Combination Oral Contraceptives",
#         "COUMARIN ANTICOAGULANTS",
#         "ANTICOAGULANTS",
#         "HMG-CoA reductase inhibitors",
#         "HMG-CoA reductase inhibitors",
#         "Resins",
#         "bile acid sequestrants",
#         "bile acid binding resin",
#         "fibrate drugs",
#         "immunosuppressants",
#         "coumarin-type anticoagulants",
#         "cytostatic agent",
#         "Potassium-Sparing Diuretics",
#         "thiazide diuretics",
#         "Potassium-sparing diuretics",
#         "histamine H2-receptor antagonists",
#         "Multivitamins",
#         "quinolones",
#         "multivitamins",
#         "quinolones",
#         "quinolones",
#         "quinolones",
#         "quinolone antimicrobial",
#         "quinolones",
#         "Nonsteroidal Anti-inflammatory Drugs",
#         "NSAIDs",
#         "nonsteroidal anti inflammatory drug",
#         "quinolone",
#         "Antidiabetic Agents",
#         "quinolones",
#         "psychotropics",
#         "monoamine oxidase inhibitors",
#         "MAOIs",
#         "psychotropics",
#         "thiazide diuretics",
#         "Thiazide diuretics",
#         "thiazide diuretics",
#         "thiazide diuretics",
#         "Cardiac glycosides",
#         "thiazide diuretics",
#         "digitalis",
#         "thiazide diuretics",
#         "Hypoglycemics",
#         "Thiazide diuretics",
#         "hypoglycemic medications",
#         "thiazide diuretic",
#         "thiazide diuretics",
#         "thiazide diuretics",
#         "Nonsteroidal anti-inflammatory agents",
#         "steroidal anti-inflammatory agent",
#         "loop diuretics",
#         "potassium sparing diuretics",
#         "thiazide diuretics",
#         "nonsteroidal anti-inflammatory agents",
#         "thiazide diuretics",
#         "benzodiazepines",
#         "dihydropyridine calcium channel blockers",
#         "HMG-CoA reductase inhibitors",
#         "NSAIDs",
#         "non-steroidal anti-inflammatory drugs",
#         "NSAIDs",
#         "loop diuretics",
#         "potassium-sparing diuretics",
#         "thiazide diuretics",
#         "potassium-sparing diuretics",
#         "potassium-sparing diuretics",
#         "beta-adrenoceptor blocking agents",
#         "non-steroidal antiinflammatory drugs",
#         "muscle relaxants",
#         "nondepolarizing muscle relaxants",
#         "NSAIDs",
#         "Nonsteroidal anti-inflammatory agents",
#         "Non-selective MAO inhibitors",
#         "MAO inhibitors",
#         "anesthetic solutions",
#         "monoamine oxidase inhibitors",
#         "tricyclic antidepressants",
#         "butyrophenones",
#         "vasopressor drugs",
#         "ergot-type oxytocic drugs",
#         "amphetamines",
#         "Antidepressants",
#         "tricyclic",
#         "sympathomimetic agents",
#         "tricyclics",
#         "MAOI antidepressants",
#         "amphetamines",
#         "Antihistamines",
#         "Antihypertensives",
#         "amphetamines",
#         "amphetamine",
#         "amphetamines",
#         "amphetamines",
#         "amphetamines",
#         "Veratrum alkaloids",
#         "veratrum alkaloids",
#         "carbamazepine epoxide",
#         "fenofibric acid",
#         "fenofibric acid",
#         "fenofibric acid",
#         "fosinoprilat",
#         "fosinoprilat",
#         "fosinoprilat"
#     ],
#     "brand": [
#         "sandimmune",
#         "sandimmune",
#         "WELLBUTRIN",
#         "NovoSeven",
#         "INDOCIN",
#         "VIRACEPT",
#         "OVCON-35"
#     ]
# }
#
#
#
# WRONG:
#  {
#     "brand": [
#         "Advantages",
#         "Effects",
#         "Eagles",
#         "S.E.M",
#         "S.E.M",
#         "D2O",
#         "Serum digoxin",
#         "125I",
#         "Validation",
#         "Determinations",
#         "125I",
#         "Combinations",
#         "Acute",
#         "Altered",
#         "Mycobacterium",
#         "Mycobacterium",
#         "Growth",
#         "BACTEC",
#         "BACKGROUND",
#         "US",
#         "Food",
#         "Drug Administration",
#         "March",
#         "Recent",
#         "OBJECTIVE",
#         "METHODS",
#         "January",
#         "August",
#         "MEDLINE",
#         "PREMEDLINE",
#         "International",
#         "Abstracts",
#         "RESULTS",
#         "SSRI",
#         "CONCLUSIONS",
#         "Studies",
#         "Stimulation",
#         "Cholecystokinin",
#         "Influence",
#         "Plasma",
#         "Release",
#         "Release",
#         "A2",
#         "A2",
#         "Differential",
#         "NANM",
#         "FI FR",
#         "Intermediate",
#         "FI",
#         "FI",
#         "FI",
#         "FI",
#         "FI",
#         "FI",
#         "Haloperidol",
#         "FI",
#         "FI",
#         "NANM",
#         "NANM",
#         "Gentamicin",
#         "Induction",
#         "TAM",
#         "TAM",
#         "TAM",
#         "Treatment",
#         "TAM",
#         "Wistar",
#         "Hippocampus",
#         "Animals",
#         "Results",
#         "ABSTRACT TRUNCATED",
#         "WORDS",
#         "Evidence",
#         "OBJECTIVES",
#         "BACKGROUND",
#         "METHODS",
#         "Hz",
#         "RESULTS",
#         "New York",
#         "Heart Association",
#         "IV",
#         "EC50",
#         "EC50",
#         "II",
#         "III",
#         "IV",
#         "IV",
#         "Radioligand",
#         "II",
#         "III",
#         "IV",
#         "CONCLUSIONS",
#         "IV",
#         "Interactions",
#         "Drug Laboratory",
#         "Test Interactions",
#         "Prolongation",
#         "Platelet",
#         "EACA",
#         "ADP",
#         "ATP",
#         "Administration",
#         "Allopurinol",
#         "Antibiotics",
#         "Chloramphenicol",
#         "May",
#         "Probenecid",
#         "May",
#         "Drug Laboratory",
#         "Test Interaction",
#         "Benedicts",
#         "Fehlings",
#         "Clinistix",
#         "Test Strip",
#         "USP",
#         "Medications",
#         "Vasodilators",
#         "Patients",
#         "Drugs",
#         "Interval Caution",
#         "Drug Laboratory",
#         "Test Interactions",
#         "Macrolides",
#         "Patients",
#         "Calcium",
#         "Concomitant",
#         "Information",
#         "Data",
#         "Antacid",
#         "Colestipol",
#         "Plasma",
#         "Patients",
#         "Coadministration",
#         "AUC",
#         "Caution",
#         "Brain",
#         "Brain",
#         "AUC",
#         "AUC",
#         "Concurrent",
#         "Drug",
#         "Interactions",
#         "Laboratory Test",
#         "Interactions",
#         "Repeat Treatment",
#         "Studies",
#         "Injection",
#         "Interactions",
#         "SIDE EFFECTS",
#         "Others",
#         "Confusion",
#         "Hypotension",
#         "Nausea",
#         "Instances",
#         "SGOT",
#         "AUC",
#         "Cmax",
#         "Animal",
#         "Drugs",
#         "Cytochrome P450IID6",
#         "SSRIs",
#         "Cmax",
#         "AUC",
#         "Concomitant",
#         "Type 1C",
#         "Studies",
#         "Levodopa",
#         "Administration",
#         "WELLBUTRIN Tablets",
#         "Drugs",
#         "Seizure Threshold",
#         "Concurrent",
#         "System",
#         "Alcohol",
#         "CONTRAINDICATIONS",
#         "Cream",
#         "Interactions",
#         "Vitamin D2",
#         "Vitamin D3",
#         "Calcitriol",
#         "Calcidiol",
#         "Thiazides",
#         "Thiazides",
#         "Digitalis",
#         "Vitamin",
#         "Reductions",
#         "Phosphate",
#         "Phosphate",
#         "Agents",
#         "Vitamin",
#         "Calcium",
#         "Supplements",
#         "Magnesium",
#         "Magnesium",
#         "Antihistamines",
#         "Effects",
#         "Concomitant",
#         "Cmax",
#         "AUC",
#         "Time",
#         "Cmax",
#         "Probenecid",
#         "A.C.",
#         "Iron",
#         "Supplements",
#         "Foods",
#         "Iron Concomitant",
#         "FeSO4",
#         "Suspension",
#         "Japan",
#         "Drug Laboratory",
#         "Test Interactions",
#         "Benedict",
#         "Fehlings",
#         "Clinistix",
#         "Tes Tape",
#         "Cephalosporins",
#         "Coombs",
#         "Nephrotoxicity",
#         "Nephrotoxicity",
#         "Chloramphenicol",
#         "Drug Laboratory",
#         "Test Interactions",
#         "CLINITEST",
#         "Benedicts",
#         "Fehlings",
#         "CLINISTIX",
#         "TES TAPE",
#         "Drugs",
#         "Fibric Acid",
#         "Derivatives",
#         "Niacin",
#         "Acid",
#         "Azole Antifungals",
#         "Muscle",
#         "Muscle",
#         "ANTACID",
#         "Magnesium Aluminum",
#         "Hydroxide",
#         "CIMETlDINE",
#         "CHOLESTYRAMINE",
#         "AUC",
#         "Cmax",
#         "Cmax",
#         "DIGOXIN",
#         "Plasma digoxin",
#         "WARFARIN",
#         "Co-",
#         "VII",
#         "AUC",
#         "Cmax",
#         "ERYTHROMYCIN",
#         "Cmax",
#         "CONCOMITANT THERAPY",
#         "ACE",
#         "NSAIDs",
#         "Alcohol",
#         "Potentiation",
#         "Dosage",
#         "ACTH",
#         "Pressor",
#         "Lithium",
#         "Refer",
#         "Drugs",
#         "Drug Laboratory",
#         "Test Interactions",
#         "Thiazides",
#         "Interactions",
#         "Vitamin D2",
#         "Vitamin D3",
#         "Calcitriol",
#         "Calcidiol",
#         "Thiazides",
#         "Thiazides",
#         "Digitalis",
#         "Vitamin",
#         "Reductions",
#         "Phosphate",
#         "Phosphate",
#         "Agents",
#         "Vitamin",
#         "Calcium",
#         "Supplements",
#         "Magnesium",
#         "Magnesium",
#         "Animal",
#         "Cmax",
#         "AUC",
#         "Calan",
#         "None",
#         "None",
#         "Use",
#         "Cyclophosphamide",
#         "Dosage",
#         "Synergism",
#         "Concurrent",
#         "1A2",
#         "2A6",
#         "2E1",
#         "3A",
#         "IC50",
#         "Protein",
#         "Entacapone",
#         "Drugs",
#         "COMT",
#         "Hormone",
#         "Levodopa",
#         "Treatment",
#         "Parkinsons",
#         "Caution",
#         "TAO",
#         "CYP3A4",
#         "Alternate",
#         "CYP3A4",
#         "CYP3A4",
#         "St. Johns",
#         "Wort",
#         "Hepatotoxicity",
#         "Patients",
#         "Impairment",
#         "International",
#         "Ratio",
#         "International",
#         "Ratio",
#         "INR",
#         "Patients",
#         "INR",
#         "Milk",
#         "Ethinyl",
#         "Substrate",
#         "CYP3A4",
#         "Inhibits CYP1A2",
#         "3A4",
#         "May",
#         "Combination",
#         "Interferes",
#         "May",
#         "Use",
#         "Antibiotics",
#         "Pregnancy",
#         "Use",
#         "Combination",
#         "Combination",
#         "Anticonvulsants",
#         "Increase",
#         "Use",
#         "Ascorbic",
#         "Doses",
#         "AUC",
#         "Benzodiazepines",
#         "Combination",
#         "Clofibric",
#         "Combination",
#         "Combination",
#         "CYP3A4",
#         "CYP3A4",
#         "Example",
#         "Griseofulvin",
#         "Griseofulvin",
#         "Use",
#         "Combination",
#         "NNRTIs",
#         "Ethinyl",
#         "Amprenavir",
#         "Rifampin",
#         "Rifampin",
#         "Use",
#         "Combination",
#         "Combination",
#         "Ethinyl",
#         "Tricyclic antidepressants",
#         "Metabolism",
#         "ETHANOL",
#         "NUTRITION",
#         "HERB INTERACTIONS",
#         "Food",
#         "Grapefruit",
#         "Herb",
#         "St Johns",
#         "Avoid",
#         "Avoid",
#         "Use",
#         "Conjunction",
#         "Drugs",
#         "AEDs",
#         "AEDs",
#         "AED AED",
#         "Concentration Concentration",
#         "Valproate",
#         "Effects",
#         "Drugs",
#         "Cmin",
#         "Cmin",
#         "Cmin",
#         "Cmin",
#         "Cmin",
#         "Valproate",
#         "Cmin",
#         "Cmin",
#         "Cmin",
#         "Cmin",
#         "AUCs",
#         "AUCs",
#         "Coadministration",
#         "Cmin",
#         "Cmin",
#         "Effects",
#         "Drugs",
#         "Valproate",
#         "Effects",
#         "Effects",
#         "Cmax",
#         "Cmin",
#         "AUC",
#         "CI",
#         "Effects",
#         "Combination",
#         "Felbamate",
#         "AUC",
#         "EXERCISED",
#         "COUMARIN ANTICOAGULANTS",
#         "GIVEN",
#         "CONJUNCTION",
#         "DOSAGE",
#         "ANTICOAGULANTS",
#         "REDUCED",
#         "MAINTAIN",
#         "PROTHROMBIN TIME",
#         "INR",
#         "DESIRED LEVEL",
#         "PREVENT BLEEDING",
#         "COMPLICATIONS",
#         "FREQUENT PROTHROMBIN",
#         "TIME INR",
#         "DETERMINATIONS",
#         "ADVISABLE",
#         "DEFINITELY DETERMINED",
#         "PROTHROMBIN TIME",
#         "INR",
#         "STABILIZED",
#         "Resins",
#         "CYP3A4",
#         "CYP2E1",
#         "CYP1A2",
#         "CYP2A6",
#         "Potentiation",
#         "INR",
#         "Concomitant",
#         "Cmax",
#         "AUC",
#         "Concomitant",
#         "Drug",
#         "Drugs",
#         "Drugs",
#         "Drug Laboratory",
#         "Test Interactions",
#         "Measurement",
#         "Jaffe",
#         "Jaffe",
#         "Patients",
#         "DOSAGE",
#         "ADMINISTRATION",
#         "Potassium",
#         "Supplements",
#         "Potassium",
#         "Potassium",
#         "Lithium",
#         "Drug Laboratory",
#         "Test Interaction",
#         "Digi- Tab",
#         "RIA Kit",
#         "RIA Kit",
#         "Substances",
#         "CYP3A4",
#         "CYP3A4",
#         "CLINICAL PHARMACOLOGY",
#         "Drug Interactions",
#         "DOSAGE",
#         "ADMINISTRATION Dosage",
#         "Adjustment",
#         "International",
#         "Ratio",
#         "INR",
#         "Patients",
#         "INR",
#         "Substances",
#         "CYP3A4",
#         "Drugs",
#         "Phase II",
#         "Drug Interactions",
#         "CLINICAL PHARMACOLOGY",
#         "Sucralfate",
#         "Metal Cations",
#         "Multivitamins",
#         "Multivitamins",
#         "Quinolones",
#         "Administration",
#         "Serum theophylline",
#         "Drugs",
#         "Cytochrome",
#         "Enzymes",
#         "CYP1A2",
#         "C.P.A",
#         "CYP3A4",
#         "CYP3A4",
#         "C.P.A",
#         "C.P.A.",
#         "Patients",
#         "C.P.A.",
#         "Nonsteroidal Anti-inflammatory",
#         "Drugs",
#         "NSAIDs",
#         "Agents",
#         "Disturbances",
#         "MAOIs",
#         "Effects",
#         "Thiazide diuretics",
#         "Effects",
#         "Amphotericin B",
#         "Corticotropin",
#         "ACTH",
#         "Concurrent",
#         "Cardiac",
#         "Concurrent",
#         "Colestipol",
#         "May",
#         "Hypoglycemics",
#         "Thiazide diuretics",
#         "Lithium",
#         "Concurrent",
#         "Effectiveness",
#         "Nonsteroidal anti-inflammatory",
#         "Thiazides",
#         "DIAGNOSTIC INTERFERENCE",
#         "Blood",
#         "Serum",
#         "Serum",
#         "Serum",
#         "Serum",
#         "Serum",
#         "PBI",
#         "Thiazides",
#         "Drugs",
#         "Drugs",
#         "Caution",
#         "CYP3A4",
#         "Substances",
#         "CYP3A4",
#         "Drugs",
#         "Substances",
#         "CYP3A4",
#         "CYP3A4",
#         "St",
#         "Johns Wort",
#         "Pretreatment",
#         "CYP3A4",
#         "Drugs",
#         "AUC",
#         "CYP3A4",
#         "CYP3A4",
#         "CYP3A4",
#         "CYP3A4",
#         "CYP3A4",
#         "CYP3A4",
#         "Gleevec",
#         "Gleevec",
#         "Ki",
#         "NSAIDs",
#         "Caution",
#         "Caution",
#         "Administration",
#         "NSAIDs",
#         "Capsules INDOCIN",
#         "Indomethacin",
#         "PRA",
#         "PRA",
#         "Isoflurane",
#         "MAC",
#         "CLINICAL PHARMACOLOGY",
#         "Concomitant",
#         "Patients",
#         "GI",
#         "Probenecid",
#         "Probenecid",
#         "NSAIDs",
#         "Lithium",
#         "Nonsteroidal anti-inflammatory",
#         "DRUG LABORATORY",
#         "TEST INTERACTIONS",
#         "EFFECT",
#         "BLOOD COAGULATION",
#         "Human",
#         "Concomitant",
#         "Indomethacin",
#         "Concomitant",
#         "Paclitaxel",
#         "Concomitant",
#         "Pneumocystis",
#         "Phenothiazines",
#         "Concurrent",
#         "Concurrent",
#         "Antidepressants",
#         "Amphetamines",
#         "MAOI antidepressants",
#         "Antihistamines",
#         "Amphetamines",
#         "Antihypertensives",
#         "Amphetamines",
#         "Ethosuximide",
#         "Amphetamines",
#         "Haloperidol",
#         "Haloperidol",
#         "Lithium",
#         "Amphetamines",
#         "Amphetamines",
#         "Amphetamines",
#         "Amphetamines",
#         "Propoxyphene",
#         "Propoxyphene",
#         "Veratrum",
#         "Amphetamines",
#         "Drug Laboratory",
#         "Test Interactions",
#         "Amphetamines",
#         "Amphetamines",
#         "Concomitant",
#         "NSAIDs",
#         "Caution",
#         "Concomitant",
#         "Inhibition",
#         "Naproxen",
#         "NSAIDs",
#         "Probenecid",
#         "Caution",
#         "Naproxen",
#         "NSAIDs",
#         "Drug Laboratory",
#         "Test Interactions",
#         "Naproxen",
#         "Porter Silber",
#         "Porter Silber",
#         "Naproxen",
#         "5HIAA",
#         "Nelfinavir",
#         "CYP3A",
#         "Coadministration",
#         "CYP3A",
#         "Nelfinavir",
#         "C.P.A",
#         "Coadministration",
#         "CYP3A",
#         "Coadministration",
#         "CYP3A",
#         "Drugs",
#         "VIRACEPT Antiarrhythmics",
#         "Drugs",
#         "Require",
#         "Reduction",
#         "Antihistamines",
#         "Administration",
#         "Coadministration",
#         "AUC",
#         "A.C",
#         "Ritonavir",
#         "Coadministration",
#         "AUC",
#         "A.C",
#         "Saquinavir",
#         "Coadministration",
#         "AUC",
#         "A.C",
#         "Antifungal",
#         "Coadministration",
#         "A.C",
#         "Agents",
#         "Rifabutin",
#         "Coadministration",
#         "AUC",
#         "A.C",
#         "Rifampin",
#         "Coadministration",
#         "A.C",
#         "Ethinyl",
#         "Estradiol",
#         "Norethindrone",
#         "Norethindrone",
#         "Coadministration",
#         "Alternate"
#     ],
#     "group": [
#         "non-myelinated",
#         "post-ganglionic",
#         "non-myelinated",
#         "non-myelinated",
#         "Serum",
#         "antigen",
#         "antigen",
#         "antigen",
#         "antipsychotic",
#         "antipsychotic clozapine",
#         "antipsychotic",
#         "antidepressant",
#         "antidepressant",
#         "cross-reactivity",
#         "antidepressants",
#         "antimicrobial",
#         "Food",
#         "cost-risk-benefit",
#         "re-results",
#         "antipsychotic",
#         "antiaggregant",
#         "beta-endorphin",
#         "beta-endorphin",
#         "beta-endorphin",
#         "beta-endorphin",
#         "beta-endorphin",
#         "beta-endorphin",
#         "beta-endorphin",
#         "beta-endorphin",
#         "beta-endorphin",
#         "non-opioid",
#         "Therapeutic drug",
#         "99mTc-methylene",
#         "antibiotic",
#         "Therapeutic drug",
#         "antiestrogen 4-hydroxytamoxifen",
#         "mono-oxidases",
#         "beta-adrenergic",
#         "Co-administration",
#         "Drug Drug",
#         "Glucose",
#         "beta-blocking agents",
#         "Co-administration",
#         "Co-administration",
#         "anticoagulant",
#         "co-administered",
#         "Co-administration",
#         "Co-administration",
#         "co-administration",
#         "antiarrhythmics",
#         "co-administration",
#         "antiarrhythmics",
#         "post-marketing",
#         "Supplements",
#         "antidepressants",
#         "anticholinergic",
#         "antihypertensive",
#         "Supplements",
#         "antibiotics",
#         "antibiotics",
#         "co-administration",
#         "co-administration",
#         "bile-acidsequestering agent",
#         "co-administration",
#         "co-administration",
#         "co-administration",
#         "Co-administration",
#         "co-administration",
#         "anti-inflammatory drugs",
#         "Non-steroidal Anti-inflammatory",
#         "non-steroidal anti-inflammatory",
#         "diuretic",
#         "antihypertensive",
#         "non-steroidal anti-inflammatory",
#         "Supplements",
#         "antifibrinolytic",
#         "Hepatotoxic medications",
#         "beta-glucuronidase",
#         "antidepressant imipramine",
#         "Co-treatment",
#         "CYP3A4 inhibitor",
#         "CYP3A4 inhibitors",
#         "Pre-treatment",
#         "non-gastrointestinal",
#         "anticoagulants",
#         "contraceptives",
#         "contraceptive",
#         "contraceptives",
#         "contraceptive",
#         "contraceptive",
#         "contraceptive",
#         "contraceptives",
#         "contraceptives",
#         "contraceptive",
#         "contraceptive",
#         "contraceptives",
#         "contraceptives",
#         "contraceptives",
#         "contraceptives",
#         "contraceptives",
#         "Non-nucleoside",
#         "contraceptives",
#         "contraceptive",
#         "contraceptives",
#         "contraceptive",
#         "contraceptives",
#         "contraceptive",
#         "contraceptive",
#         "contraceptives",
#         "contraceptives",
#         "contraceptives",
#         "Food",
#         "contraceptives",
#         "contraceptives",
#         "Contraceptives",
#         "Anticoagulants CAUTION",
#         "Drug drug",
#         "anticoagulants",
#         "-hydroxy-iso-pravastatin",
#         "Cytosine",
#         "antifungal",
#         "Supplements",
#         "Diuretics",
#         "Diuretics",
#         "diuretics",
#         "anticoagulant",
#         "Pharmacokinetics Drug",
#         "CYP3A4 inhibitors",
#         "Serum",
#         "multi-day",
#         "anticoagulation",
#         "Enzymes",
#         "anti",
#         "anti-inflammatory agent",
#         "diuretic",
#         "antihypertensive",
#         "anti-inflammatory agents",
#         "Blood",
#         "Serum",
#         "Serum",
#         "Serum",
#         "Serum",
#         "Serum",
#         "CYP3A4 inhibitor",
#         "Co-medications",
#         "triazolo-benzodiazepines",
#         "anticoagulation",
#         "post-marketing",
#         "non-steroidal anti-inflammatory",
#         "diuretic",
#         "antihypertensive",
#         "diuretics",
#         "diuretics",
#         "antihypertensive",
#         "beta-adrenoceptor",
#         "non-steroidal antiinflammatory",
#         "antihypertensive",
#         "Non-selective MAO",
#         "non-selective MAO",
#         "antidepressants",
#         "antidepressants",
#         "d-amphetamine",
#         "d-amphetamine",
#         "antihypertensives",
#         "co-administration",
#         "anticonvulsant",
#         "co-administration",
#         "anticonvulsant",
#         "corticosteroid",
#         "antidepressants",
#         "anticoagulants",
#         "antihypertensive",
#         "m-dinitrobenzene",
#         "17-hydroxy-corticosteroid",
#         "Protease Inhibitors",
#         "Transcriptase Inhibitors",
#         "contraceptive"
#     ],
#     "drug_n": [
#         "C",
#         "C",
#         "3H",
#         "DRL",
#         "DRL",
#         "KRM",
#         "KRM",
#         "KRM",
#         "KRM",
#         "KRM",
#         "E-strain",
#         "A-strain",
#         "E-strain",
#         "A-strain",
#         "0.5-2",
#         "FR",
#         "FR",
#         "FR",
#         "norepinephrine uptake-1",
#         "norepinephrine uptake-1",
#         "norepinephrine uptake-1",
#         "norepinephrine uptake-1",
#         "norepinephrine uptake-1",
#         "ATP",
#         "urine",
#         "Dopamine",
#         "Dopamine Antagonists",
#         "dopamine",
#         "dopamine",
#         "dopamine",
#         "Catecholamine",
#         "catecholamine",
#         "Calcium",
#         "azole antifungals",
#         "P450 3A4",
#         "Endocrine Function",
#         "cholesterol",
#         "alkaline",
#         "P450",
#         "Nicotine Transdermal",
#         "urine",
#         "intestine",
#         "Geocillin",
#         "carbenicillin",
#         "urine",
#         "urine",
#         "urine",
#         "Magnesium",
#         "cerivastatin",
#         "cerivastatin",
#         "cerivastatin",
#         "cerivastatin AUC",
#         "cerivastatin",
#         "cerivastatin",
#         "cerivastatin",
#         "cerivastatin",
#         "cerivastatin AUC",
#         "P450 3A4",
#         "cerivastatin",
#         "thiazide diuretics",
#         "thiazide diuretics",
#         "determine",
#         "urine",
#         "intestine",
#         "alcohol",
#         "monoamine",
#         "monoamine",
#         "Cerubidine",
#         "Cerubidine",
#         "Cerubidine",
#         "Cerubidine",
#         "Cerubidine",
#         "swine",
#         "xanthine",
#         "erlotinib AUC",
#         "erlotinib AUC",
#         "alkaline",
#         "Protease",
#         "Grapefruit",
#         "phenytoin Cmin",
#         "nine",
#         "Carbamazepine",
#         "Carbamazepine",
#         "creatinine",
#         "creatinine",
#         "P450",
#         "atorvastatin AUC",
#         "atorvastatin Cmax",
#         "Cytosine",
#         "creatinine",
#         "creatinine",
#         "creatinine",
#         "fosinopril",
#         "fosinopril",
#         "Fosinopril",
#         "Fosinopril",
#         "thiazide diuretics",
#         "Potassium",
#         "lithium",
#         "fosinopril",
#         "fosinopril",
#         "histamine H2",
#         "alkaline",
#         "quinolone antimicrobial",
#         "P450",
#         "quinolone",
#         "monoamine",
#         "thiazide diuretics",
#         "thiazide diuretics",
#         "thiazide diuretics",
#         "thiazide diuretics",
#         "thiazide diuretics",
#         "thiazide diuretic",
#         "thiazide diuretics",
#         "thiazide diuretics",
#         "urine",
#         "thiazide diuretics",
#         "determine",
#         "urine",
#         "thiazide diuretics",
#         "iodine",
#         "P450",
#         "dihydropyridine",
#         "P450",
#         "acetaminophen O-glucuronidation",
#         "thiazide diuretics",
#         "determine",
#         "dexamethasone",
#         "baseline",
#         "nine",
#         "tranylcypromine",
#         "phenelzine",
#         "pargyline HC1",
#         "urine",
#         "monoamine",
#         "norepinephrine",
#         "dopamine",
#         "norepinephrine",
#         "amphetamine",
#         "dopamine",
#         "Lithium",
#         "lithium",
#         "amphetamine CNS",
#         "P450 3A",
#         "dihydropyridine",
#         "quinidine Antihistamines",
#         "terfenadine Antimigraine",
#         "rifampin Benzodiazepines",
#         "triazolam GI",
#         "Protease",
#         "Estradiol"
#     ]
# }

# %% [markdown]
# ## Conclusions
#
# - Objectives achieved
# - Just by extracting simple rules based on data analysis we were able to achieve the minimum score
# - Importance of the analysis of each independent class in order to focus on that and improve those classes with less accuracy.
